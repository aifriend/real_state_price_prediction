# %% [markdown]
# ## Analisis Exploratorio
# ###### Describer la situación del mercado de alquileres temporales en Airbnb en la ciudad de Madrid a nivel general. Se valorarán las descripciones visuales y la explotación de la riqueza de los datos. Por ejemplo, haciendo uso de los datos geoespaciales y/o del lenguaje natural.

# %% [markdown]
# #### Carga de datos

# %%
# run python script to load data
# !python ../src/data/make_dataset.py /Users/bigboy/Downloads/coding/real_state_price_prediction/data/raw /Users/bigboy/Downloads/coding/real_state_price_prediction/data/interim
# Out:
# 2024-05-06 13:04:42,086 - __main__ - INFO - making final data set from raw data
# 2024-05-06 13:04:42,087 - __main__ - INFO - Load processed listings from: /Users/bigboy/Downloads/coding/real_state_price_prediction/data/raw
# 2024-05-06 13:04:42,087 - rLogger - INFO - Load processed listings from: /Users/bigboy/Downloads/coding/real_state_price_prediction/data/raw/listings.csv
# 2024-05-06 13:04:42,087 - rLogger - INFO - Load processed listings from: /Users/bigboy/Downloads/coding/real_state_price_prediction/data/raw/listings.csv
# 2024-05-06 13:04:42,299 - rLogger - INFO -       id  ... availability_365
# 0   6369  ...               82
# 1  21853  ...              162
# 2  23001  ...              213
# 3  24805  ...              362
# 4  24836  ...              342
#
# [5 rows x 16 columns]
# 2024-05-06 13:04:42,299 - rLogger - INFO -       id  ... availability_365
# 0   6369  ...               82
# 1  21853  ...              162
# 2  23001  ...              213
# ...

# %% [markdown]
# #### Extracción de características

# %%
# !python ../src/features/build_features.py /Users/bigboy/Downloads/coding/real_state_price_prediction/data/interim /Users/bigboy/Downloads/coding/real_state_price_prediction/data/processed
# Out:
# 2024-05-06 13:08:08,358 - __main__ - INFO - making final data set from raw data
# 2024-05-06 13:08:08,358 - rLogger - INFO - Load full listings...
# 2024-05-06 13:08:08,358 - rLogger - INFO - Load full listings...
# 2024-05-06 13:08:10,819 - rLogger - INFO - Processing listings...
# 2024-05-06 13:08:10,819 - rLogger - INFO - Processing listings...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21495 entries, 0 to 21494
# Data columns (total 59 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              21495 non-null  int64
#  1   neighbourhood_group             21495 non-null  object
#  2   neighbourhood                   21495 non-null  object
#  3   latitude                        21495 non-null  float64
#  4   longitude                       21495 non-null  float64
#  5   room_type                       21495 non-null  object
# ...

# %% [markdown]
# #### Exploracion de datos

# %%
# !python ../src/visualization/show_analysis.py /Users/bigboy/Downloads/coding/real_state_price_prediction/data/processed
# Out:
# 2024-05-06 14:54:15,324 - __main__ - INFO - I explored the data to check if there are trends between the explanatory variables and the target variable.
# 2024-05-06 14:54:15,324 - rLogger - INFO - Load processed reviews from: /Users/bigboy/Downloads/coding/real_state_price_prediction/data/processed/reviews.csv.gz
# 2024-05-06 14:54:15,324 - rLogger - INFO - Load processed reviews from: /Users/bigboy/Downloads/coding/real_state_price_prediction/data/processed/reviews.csv.gz
# Figure(3000x1200)
# Figure(1000x600)
# Figure(800x600)
# Figure(1000x600)
# Figure(1200x800)
# 2024-05-06 14:54:17,830 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %% [markdown]
# #### Train

# %%
# !python ../src/models/train_model.py /Users/bigboy/Downloads/coding/real_state_price_prediction/data/processed
# Out:
# 2024-05-06 17:13:24,832 - __main__ - INFO - Training models...
# 2024-05-06 17:13:24,833 - rLogger - INFO - Load processed listings from: /Users/bigboy/Downloads/coding/real_state_price_prediction/data/processed/listings.csv.gz
# 2024-05-06 17:13:24,833 - rLogger - INFO - Load processed listings from: /Users/bigboy/Downloads/coding/real_state_price_prediction/data/processed/listings.csv.gz
# 2024-05-06 17:13:25,296 - rLogger - INFO - neighbourhood_group ==> Apply label encoder with label {'Chamartín': 4, 'Latina': 9, 'Arganzuela': 0, 'Centro': 3, 'Fuencarral - El Pardo': 7, 'Salamanca': 14, 'Tetuán': 16, 'Ciudad Lineal': 6, 'Chamberí': 5, 'Villaverde': 20, 'Hortaleza': 8, 'Moncloa - Aravaca': 10, 'Carabanchel': 2, 'Retiro': 13, 'San Blas - Canillejas': 15, 'Barajas': 1, 'Usera': 17, 'Puente de Vallecas': 12, 'Villa de Vallecas': 19, 'Moratalaz': 11, 'Vicálvaro': 18}
# ...

# %% [markdown]
# #### Predict

# %%
# !python ../src/models/predict_model.py /Users/bigboy/Downloads/coding/real_state_price_prediction/data/processed
# Out:
# 2024-05-06 22:31:11,908 - __main__ - INFO - Predict listings price...
# 2024-05-06 22:31:11,909 - rLogger - INFO - Load processed listings from: /Users/bigboy/Downloads/coding/real_state_price_prediction/data/processed/listings.csv.gz
# 2024-05-06 22:31:11,909 - rLogger - INFO - Load processed listings from: /Users/bigboy/Downloads/coding/real_state_price_prediction/data/processed/listings.csv.gz
# 2024-05-06 22:31:12,996 - rLogger - INFO - neighbourhood_group ==> Apply label encoder with label {'Chamartín': 4, 'Latina': 9, 'Arganzuela': 0, 'Centro': 3, 'Fuencarral - El Pardo': 7, 'Salamanca': 14, 'Tetuán': 16, 'Ciudad Lineal': 6, 'Chamberí': 5, 'Villaverde': 20, 'Hortaleza': 8, 'Moncloa - Aravaca': 10, 'Carabanchel': 2, 'Retiro': 13, 'San Blas - Canillejas': 15, 'Barajas': 1, 'Usera': 17, 'Puente de Vallecas': 12, 'Villa de Vallecas': 19, 'Moratalaz': 11, 'Vicálvaro': 18}
# ...
